# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def roi(image):
    kotak = np.array([
        [(259, 600), (633, 596), (800, 200), (600, 200)]
    ])
    mask = np.zeros_like(image)
    cv2.fillPoly(mask, kotak, (0, 0, 200))
    masked_image = cv2.bitwise_and(image, mask)
    return masked_image

video = cv2.VideoCapture('videos/terusan_sulfat_utara.mp4')
count = 1

# %%
# while True:
#     ret, frame = video.read()
    
#     if not ret:
#         break

#     frame = cv2.resize(frame, (1020, 600) )
#     roi_putih = roi(frame)
#     cv2.imshow("putih", roi_putih)
    
#     hsv_frame = cv2.cvtColor(roi_putih, cv2.COLOR_BGR2HSV)

#     lower_white = np.array([0, 0, 200])
#     upper_white = np.array([180, 30, 255])
#     mask = cv2.inRange(roi_putih, lower_white, upper_white)

#     result = cv2.bitwise_and(frame, frame, mask=mask)

#     # Temukan kontur pada gambar hasil
#     contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
#     # Gambar kotak pada setiap kontur
#     for contour in contours:
#         area = cv2.contourArea(contour)
#         x, y, w, h = cv2.boundingRect(contour)
#         if area > 50:
#             print(f"num {count} x:{x} y:{y} w:{w} h:{h} area:{area} ratio:{h/w}")
#             cv2.putText(frame, str(count)  , (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
#             cv2.rectangle(frame,(x,y),(x+w , y+h),(0,255,0),2)
#             count += 1

#     cv2.imshow('Hasil Deteksi', frame)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# video.release()
# cv2.destroyAllWindows()

# %%
image = cv2.imread('images/roi-motor/SCOOPY/119.jpg')

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Menghilangkan sumbu koordinat
plt.show()

# %%
# Ubah citra menjadi ruang warna HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
plt.imshow(cv2.cvtColor(hsv_image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Menghilangkan sumbu koordinat
plt.show()

# %%
# Tentukan rentang warna putih dalam HSV
lower_white = np.array([0, 0, 200])
upper_white = np.array([180, 30, 255])

# Buat mask dengan rentang warna putih
mask = cv2.inRange(hsv_image, lower_white, upper_white)
plt.imshow(cv2.cvtColor(mask, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Menghilangkan sumbu koordinat
plt.show()

# %%
# Aplikasikan mask ke citra asli
result = cv2.bitwise_and(image, image, mask=mask)
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Menghilangkan sumbu koordinat
plt.show()

# %%
# Temukan kontur pada gambar hasil
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Gambar kotak pada setiap kontur
for contour in contours:
    area = cv2.contourArea(contour)
    x, y, w, h = cv2.boundingRect(contour)
    if area > 400:
        print(f"num {count} x:{x} y:{y} w:{w} h:{h} area:{area} ratio:{h/w}")
        cv2.rectangle(image,(x,y),(x+w , y+h),(0,255,0),2)
        count += 1
    print(contour)
    
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Menghilangkan sumbu koordinat
plt.show()
# Out:
# [[[  9 146]]]
# [[[ 12 131]]
#
#  [[ 12 133]]
#
#  [[ 11 134]]
#
#  [[ 11 138]]
#
#  [[ 10 139]]
#
#  [[ 10 142]]
#
#  [[ 10 140]]
#
#  [[ 11 139]]
#
#  [[ 11 136]]
#
#  [[ 12 135]]]
# [[[ 31 129]]
#
#  [[ 31 132]]
#
#  [[ 30 133]]
#
#  [[ 30 135]]
#
#  [[ 29 136]]
#
#  [[ 29 140]]
#
#  [[ 28 141]]
#
#  [[ 28 144]]
#
#  [[ 27 145]]
#
#  [[ 27 146]]
#
#  [[ 28 146]]
#
#  [[ 28 143]]
#
#  [[ 29 142]]
#
#  [[ 29 137]]
#
#  [[ 30 136]]
#
#  [[ 30 134]]
#
#  [[ 31 133]]]
# [[[ 16 114]]
#
#  [[ 15 115]]
#
#  [[ 15 122]]
#
#  [[ 14 123]]
#
#  [[ 14 124]]
#
#  [[ 15 125]]
#
#  [[ 15 126]]
#
#  [[ 15 125]]
#
#  [[ 16 124]]
#
#  [[ 16 123]]
#
#  [[ 18 121]]
#
#  [[ 17 121]]
#
#  [[ 16 120]]
#
#  [[ 16 119]]
#
#  [[ 15 118]]
#
#  [[ 16 117]]]
# [[[ 67 107]]
#
#  [[ 66 108]]
#
#  [[ 64 108]]
#
#  [[ 63 109]]
#
#  [[ 65 109]]
#
#  [[ 66 108]]
#
#  [[ 68 108]]
#
#  [[ 68 107]]]
# [[[ 10 100]]
#
#  [[ 10 104]]
#
#  [[ 12 104]]
#
#  [[ 13 105]]
#
#  [[ 20 105]]
#
#  [[ 21 106]]
#
#  [[ 27 106]]
#
#  [[ 28 107]]
#
#  [[ 27 108]]
#
#  [[ 24 108]]
#
#  [[ 23 109]]
#
#  [[ 24 110]]
#
#  [[ 27 110]]
#
#  [[ 28 111]]
#
#  [[ 36 111]]
#
#  [[ 36 110]]
#
#  [[ 34 110]]
#
#  [[ 33 109]]
#
#  [[ 34 108]]
#
#  [[ 37 108]]
#
#  [[ 37 104]]
#
#  [[ 36 104]]
#
#  [[ 35 103]]
#
#  [[ 31 103]]
#
#  [[ 30 102]]
#
#  [[ 25 102]]
#
#  [[ 24 101]]
#
#  [[ 19 101]]
#
#  [[ 18 100]]]
# [[[39 80]]
#
#  [[39 81]]
#
#  [[38 82]]
#
#  [[38 86]]
#
#  [[39 87]]
#
#  [[40 86]]
#
#  [[41 86]]
#
#  [[42 87]]
#
#  [[43 86]]
#
#  [[44 86]]
#
#  [[45 85]]
#
#  [[44 84]]
#
#  [[45 83]]
#
#  [[46 83]]
#
#  [[46 81]]
#
#  [[40 81]]]
# num 1 x:12 y:68 w:25 h:29 area:451.0 ratio:1.16
# [[[19 68]]
#
#  [[18 69]]
#
#  [[17 69]]
#
#  [[14 72]]
#
#  [[14 74]]
#
#  [[13 75]]
#
#  [[13 76]]
#
#  [[12 77]]
#
#  [[12 78]]
#
#  [[13 79]]
#
#  [[12 80]]
#
#  [[15 83]]
#
#  [[17 83]]
#
#  [[18 84]]
#
#  [[18 88]]
#
#  [[19 89]]
#
#  [[19 92]]
#
#  [[21 94]]
#
#  [[21 95]]
#
#  [[22 95]]
#
#  [[23 96]]
#
#  [[29 96]]
#
#  [[30 95]]
#
#  [[31 95]]
#
#  [[34 92]]
#
#  [[34 91]]
#
#  [[35 90]]
#
#  [[35 88]]
#
#  [[36 87]]
#
#  [[36 76]]
#
#  [[34 74]]
#
#  [[34 72]]
#
#  [[33 71]]
#
#  [[32 71]]
#
#  [[31 70]]
#
